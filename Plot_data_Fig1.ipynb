# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Panel-C" data-toc-modified-id="Panel-C-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Panel C</a></span><ul class="toc-item"><li><span><a href="#for-SI-also-the-real-and-imaginary-parts" data-toc-modified-id="for-SI-also-the-real-and-imaginary-parts-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>for SI also the real and imaginary parts</a></span></li></ul></li><li><span><a href="#Panel-D" data-toc-modified-id="Panel-D-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Panel D</a></span></li><li><span><a href="#Panel-IVC" data-toc-modified-id="Panel-IVC-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Panel IVC</a></span></li><li><span><a href="#SM-50-Hz" data-toc-modified-id="SM-50-Hz-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>SM 50 Hz</a></span><ul class="toc-item"><li><span><a href="#quantifying" data-toc-modified-id="quantifying-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>quantifying</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import stlabutils
import pickle
from src.algo_peakheights import S11_fitting_full
import scipy.signal
from src.model_currentbias import f0 as f0model
from scipy.interpolate import interp1d

# %% [markdown]
# # Panel C

# %%
fpath = glob.glob('data_raw/F6*VNA*/*.dat')
mydata = stlabutils.readdata.readdat(fpath[0])
# Out:
# ['Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)', 'Temperature (K)']

# %%
myline = mydata[30]

# %%
plt.plot(myline['Frequency (Hz)'],myline['S21dB (dB)'])
plt.show()
plt.close()

fitwidth=None,
trimwidth=5, 
ftype='A', 
doplots=False, 
margin=51

# %%
freqs = myline['Frequency (Hz)'].values
S11complex = myline['S21re ()'] + 1j * myline['S21im ()']
S11complex = S11complex.values
params, _, _, _ = stlabutils.S11fit(freqs, S11complex, ftype='A', doplots=True)
# Out:
# Max index:  392  Max frequency:  7437840000.0
# Peak limits:  356 425
# Lower edge:  7437120000.0  Center:  7437840000.0  Upper edge:  7438500000.0  Points in width:  69
# 1001 1001
# -0.1518984428477531 2.0903434481821183e-11 4444.264032776505 -5.978959319241067e-07
# [[Variables]]
#     a:   35.6364937 +/- 14.0598003 (39.45%) (init = -0.1518984)
#     b:  -9.6000e-09 +/- 3.7798e-09 (39.37%) (init = 2.090343e-11)
#     c:   6.4659e-19 +/- 2.5404e-19 (39.29%) (init = 0)
#     ap:  4298.28159 +/- 2.04140671 (0.05%) (init = 4444.264)
#     bp: -5.7824e-07 +/- 2.7419e-10 (0.05%) (init = -5.978959e-07)
#     cp:  0 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b, c)   = -1.000
#     C(a, b)   = -1.000
#     C(a, c)   =  1.000
#     C(ap, bp) = -1.000
# [[Variables]]
#     a:      35.63649 (fixed)
#     b:     -9.599997e-09 (fixed)
#     c:      6.465886e-19 (fixed)
#     ap:     4298.282 (fixed)
#     bp:    -5.782448e-07 (fixed)
#     cp:     0 (fixed)
#     Qint:   27574.8641 +/- 445.025427 (1.61%) (init = 18850.69)
#     Qext:   10725.1573 +/- 48.0522342 (0.45%) (init = 7547.78)
#     f0:     7.4378e+09 +/- 3005.08367 (0.00%) (init = 7.43784e+09)
#     theta:  0.07373033 +/- 0.00448033 (6.08%) (init = 0)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(f0, theta)  = -0.718
#     C(Qint, Qext) =  0.278
# QLoaded =  7721.790855213564
# /home/feschmidt/git/stlabutils/utils/S11fit.py:734: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal', 'datalim')
# [[Variables]]
#     a:      32.1404484 +/- 2.37890553 (7.40%) (init = 35.63649)
#     b:     -8.6624e-09 +/- 6.3948e-10 (7.38%) (init = -9.599997e-09)
#     c:      5.8372e-19 +/- 4.2976e-20 (7.36%) (init = 6.465886e-19)
#     ap:     4370.63715 +/- 0.46352979 (0.01%) (init = 4298.282)
#     bp:    -5.8797e-07 +/- 6.2297e-11 (0.01%) (init = -5.782448e-07)
#     cp:     0 (fixed)
#     Qint:   25429.2924 +/- 120.172799 (0.47%) (init = 27574.86)
#     Qext:   9883.79680 +/- 12.9604069 (0.13%) (init = 10725.16)
#     f0:     7.4378e+09 +/- 952.900991 (0.00%) (init = 7.437813e+09)
#     theta:  0.08159137 +/- 0.00133185 (1.63%) (init = 0.07373033)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(b, c)       = -1.000
#     C(a, b)       = -1.000
#     C(a, c)       =  1.000
#     C(ap, bp)     = -1.000
#     C(f0, theta)  = -0.755
#     C(bp, Qext)   =  0.407
#     C(ap, Qext)   = -0.407
#     C(Qint, Qext) =  0.345
#     C(c, Qint)    =  0.297
#     C(b, Qint)    = -0.297
#     C(a, Qint)    =  0.297
#     C(a, theta)   = -0.207
#     C(b, theta)   =  0.207
#     C(c, theta)   = -0.207
#     C(a, f0)      =  0.157
#     C(b, f0)      = -0.157
#     C(c, f0)      =  0.157
#     C(c, Qext)    =  0.140
#     C(b, Qext)    = -0.140
#     C(a, Qext)    =  0.140
#     C(bp, Qint)   =  0.131
#     C(ap, Qint)   = -0.131
#     C(ap, f0)     = -0.113
#     C(bp, f0)     =  0.113
# QLoaded =  7117.416363773581
# /home/feschmidt/git/stlabutils/utils/S11fit.py:772: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.axes().set_aspect('equal', 'datalim')

# %%
fitresbg = stlabutils.utils.S11fit.S11func(freqs, params, ftype='A')  # fit with background removed
fitresnobg = stlabutils.utils.S11fit.S11theo(freqs, params, ftype='A')  # fit with background removed
bgonly = -stlabutils.utils.S11fit.S11back(freqs, params)  # background only

# %%
x,y = freqs/1e9,(S11complex/bgonly+1)*np.exp(-1j*params['theta'].value)-1  # divide off the background
xtheo,ytheo = x,(fitresbg/bgonly+1)*np.exp(-1j*params['theta'].value)-1  # divide off the background

plt.plot(x,np.real(y),'o',c='C0',markerfacecolor='none',label='Re(S$_{11}$)')
plt.plot(xtheo,np.real(ytheo),c='k')
plt.plot(x,np.imag(y),'o',c='C1',markerfacecolor='none',label='Im(S$_{11}$)')
plt.plot(xtheo,np.imag(ytheo),c='k')
plt.xlabel('Frequency (GHz)')
plt.ylabel(r'S$_{11}$ ()')
plt.xlim(7.432,7.444)
plt.legend(loc='lower right')
plt.show()
plt.close()

# %%
panel_c = {'xmeas':x,'ymeas':y,'ymeaslabel':'data','f0':params['f0'].value/1e9,
          'xtheo':xtheo,'ytheo':ytheo,'ytheolabel':'fit',
          'xlabel':'Frequency (GHz)','ylabel':r'|S$_{11}$| (normalized)'}
pickle.dump(panel_c,open('data_final/fig1_panel_c.pkl','wb'))

# %% [markdown]
# ## for SI also the real and imaginary parts

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
plt.plot(np.angle(y),np.abs(y),'o',markerfacecolor='none')
plt.plot(np.angle(ytheo),np.abs(ytheo),c='k')
ax.set_rlim(0,1.1)
plt.show()
plt.close()

# %% [markdown]
# # Panel D

# %%
myfile = glob.glob('data_raw/F30_50Hz_noise_debugging/F30_2019_03_22_14.09.44_VNA_vs_current_10uAalloffcleanracks/*.dat')
myfile = myfile[0]
print(myfile)
# Out:
# data_raw/F30_50Hz_noise_debugging/F30_2019_03_22_14.09.44_VNA_vs_current_10uAalloffcleanracks/F30_2019_03_22_14.09.44_VNA_vs_current_10uAalloffcleanracks.dat

# %%
popt = pickle.load(open('data_processed/sensitivity_estimation/popt_simulation_JJarrays.pkl', 'rb'))

# %%
from src.model_currentbias import f0
xtheo = np.linspace(0,popt[2],401)
ytheo = f0(xtheo,*popt)
# Out:
# /home/feschmidt/CloudStation/papers/current_detection/data_processing_zenodo/src/model_currentbias.py:21: RuntimeWarning: divide by zero encountered in true_divide
#   return Phi0 / (2*pi*np.sqrt(Ic**2 - I**2))

# %%
data = stlabutils.readdata.readdat(myfile)
mymtx = stlabutils.framearr_to_mtx(data,'S21dB (dB)',xkey='Frequency (Hz)',ykey='Iset (A)')
mymtx.applystep('sub_cbc 40,40')
mymtx.applystep('rotate_ccw')
mymtx.pmtx.head()
# Out:
# ['Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)', 'T (K)', 'Time (s)', 'Iset (A)']
# ('Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)', 'T (K)', 'Time (s)', 'Iset (A)')
# Iset (A)
# Frequency (Hz)
# (50, 2001)
# sub_cbc [40.0, 40.0]
# rotate_ccw []
# Iset (A)        0.000000e+00  2.040816e-07  4.081633e-07  6.122449e-07  \
# Frequency (Hz)
# 7.460000e+09       -0.252935      0.133755     -0.113165     -0.183697
# 7.459920e+09       -0.212602      0.159820      0.252054      0.369840
# 7.459840e+09       -0.279940      0.067184      0.492398     -0.027847
# 7.459760e+09       -0.086463     -0.136753     -0.345111     -0.071121
# 7.459680e+09       -0.056178      0.032768      0.067054      0.267476
#
# Iset (A)        8.163265e-07  1.020408e-06  1.224490e-06  1.428571e-06  \
# Frequency (Hz)
# 7.460000e+09        0.135325     -0.038612      0.235767      0.064257
# 7.459920e+09       -0.042391     -0.122888     -0.191680     -0.182008
# 7.459840e+09       -0.172768      0.326127      0.018779     -0.050384
# 7.459760e+09        0.507502     -0.103068     -0.243003      0.121599
# 7.459680e+09       -0.184012     -0.085477     -0.292505      0.148113
#
# Iset (A)        1.632653e-06  1.836735e-06  ...  8.163265e-06  8.367347e-06  \
# Frequency (Hz)                              ...
# 7.460000e+09        0.101044     -0.020825  ...     -0.057279      0.159846
# 7.459920e+09       -0.482022     -0.687948  ...     -0.195575      0.065567
# 7.459840e+09       -0.076783      0.541703  ...     -0.158991     -0.019470
# 7.459760e+09        0.067212      0.133703  ...     -0.031480     -0.008725
# 7.459680e+09       -0.278832     -0.268480  ...     -0.084020     -0.230178
#
# Iset (A)        8.571429e-06  8.775510e-06  8.979592e-06  9.183673e-06  \
# Frequency (Hz)
# 7.460000e+09        0.251555     -0.289438     -0.385536      0.183868
# 7.459920e+09       -0.171212      0.258191     -0.751921      0.296910
# 7.459840e+09       -0.050392     -0.035389     -0.014499      0.129143
# 7.459760e+09        0.125955     -0.104616     -0.111350      0.268330
# 7.459680e+09       -0.692127      0.053663      0.101005      0.266992
#
# Iset (A)        9.387755e-06  9.591837e-06  9.795918e-06  1.000000e-05
# Frequency (Hz)
# 7.460000e+09        0.103753      0.116039     -0.221726      0.250318
# 7.459920e+09       -0.043693      0.312612      0.129167     -0.365364
# 7.459840e+09        0.146718     -0.110570      0.553719      0.222488
# 7.459760e+09       -0.130468     -0.245234      0.123673      0.146223
# 7.459680e+09        0.160452     -0.215624      0.068566      0.210262
#
# [5 rows x 50 columns]

# %%
(S11res_vs_I_clip, mydfs_clip) = pickle.load(open("data_processed/sensitivity_estimation/fitpars_derivatives_vs_Is_F30_fulldata.pkl", "rb"))
mydfs_clip[0].head()
# Out:
#    Frequency (Hz)  Iset (A)       f0 (Hz)              S11 ()  S11phase (rad)  \
# 0    7.300000e+09       0.0  7.437844e+09 -0.001664+0.003095j        2.064111
# 1    7.300080e+09       0.0  7.437844e+09 -0.001271+0.003464j        1.922384
# 2    7.300160e+09       0.0  7.437844e+09 -0.000957+0.003284j        1.854408
# 3    7.300240e+09       0.0  7.437844e+09 -0.000835+0.003474j        1.806663
# 4    7.300320e+09       0.0  7.437844e+09 -0.000900+0.003534j        1.820145
#
#    S11re ()  S11im ()  S11abs ()           S11fit ()  S11fitphase (rad)  \
# 0 -0.001664  0.003095   0.003514 -0.000725+0.003515j           1.774321
# 1 -0.001271  0.003464   0.003689 -0.000562+0.003544j           1.727937
# 2 -0.000957  0.003284   0.003421 -0.000397+0.003565j           1.681552
# 3 -0.000835  0.003474   0.003573 -0.000231+0.003579j           1.635168
# 4 -0.000900  0.003534   0.003646 -0.000064+0.003585j           1.588784
#
#    S11fitre ()  S11fitim ()  S11fitabs ()       S11fitnobg ()  \
# 0    -0.000725     0.003515      0.003589 -1.000499+0.004502j
# 1    -0.000562     0.003544      0.003588 -1.000499+0.004504j
# 2    -0.000397     0.003565      0.003587 -1.000499+0.004507j
# 3    -0.000231     0.003579      0.003587 -1.000500+0.004509j
# 4    -0.000064     0.003585      0.003586 -1.000500+0.004512j
#
#    S11fitnobgphase (rad)  S11fitnobgre ()  S11fitnobgim ()  S11fitnobgabs ()
# 0               3.137093        -1.000499         0.004502          1.000509
# 1               3.137091        -1.000499         0.004504          1.000509
# 2               3.137088        -1.000499         0.004507          1.000510
# 3               3.137085        -1.000500         0.004509          1.000510
# 4               3.137083        -1.000500         0.004512          1.000510

# %%
wbval=(0.4, 0.4)
cmap='viridis'
lims = np.percentile(mymtx.pmtx.values, (wbval[0], 100 - wbval[1]))
vmin = lims[0]
vmax = lims[1]
extents = mymtx.getextents()
dx = np.diff(mymtx.pmtx.axes[1].values)[0]
dy = np.diff(mymtx.pmtx.axes[0].values)[0]

x = mymtx.pmtx.axes[1]-dx/2 # why??
y = mymtx.pmtx.axes[0]-dy/2
X,Y = np.meshgrid(x,y)
Z = mymtx.pmtx.values

# Z = Z/np.linalg.norm(Z)
# normalizing
Z = Z - Z.min(axis=0)
Z = Z / (Z.min(axis=0) - Z.max(axis=0))
Z = -Z

fig,ax=plt.subplots()
plt.pcolormesh(X/1e-6,Y/1e9,Z,cmap=cmap)#,vmin=vmin,vmax=vmax)

# plt.plot(f0_vs_Iset[0]/1e-6,f0_vs_Iset[1]/1e9,c='C1',alpha=.8,ls='-',lw=2)
plt.plot(xtheo/1e-6,ytheo/1e9,c='C1',alpha=.8,ls='-',lw=2)
plt.xlim(0,8.5)
plt.ylim(7.32,7.45)

plt.ylabel('Frequency (GHz)')
plt.xlabel('Bias current (µA)')

plt.colorbar()

plt.show()
plt.close()

# %%
panel_d = {'x':X/1e-6,'y':Y/1e9,'z':Z,
          'xtheo':xtheo/1e-6,'ytheo':ytheo/1e9,
          'xlabel':'Bias current (µA)','ylabel':'Frequency (GHz)','zlabel':r'|S$_{11}$| (norm.)'}
pickle.dump(panel_d,open('data_final/fig1_panel_d.pkl','wb'))

# %%
for block in data[:-5:5]:
    x = block['Frequency (Hz)']/1e9
    y = block['S21dB (dB)']
    Is = '{:.1f} µA'.format(block['Iset (A)'][0]/1e-6)
    plt.plot(x,y,label=Is)
plt.xlabel('Frequency (GHz)')
plt.ylabel(r'|$S_{11}$| (dB)')
plt.legend(loc='best')
plt.tight_layout()
plt.show()
plt.close()

# %% [markdown]
# # Panel IVC

# %%
mypath = glob.glob('data_raw/F14*/*.dat')
data = stlabutils.readdata.readdat(mypath[0])
data=data[0]
data.head()
# Out:
# ['Time (s)', 'T (K)', 'Iset (A)', 'Vmeas (V)', 'Rmeas (Ohm)']
#     Time (s)    T (K)  Iset (A)  Vmeas (V)  Rmeas (Ohm)
# 0  10.629063  0.01474  -0.00002  -0.002174   108.689776
# 1  10.655065  0.01474  -0.00002  -0.002164   108.732470
# 2  10.681068  0.01474  -0.00002  -0.002153   108.732517
# 3  10.707070  0.01474  -0.00002  -0.002143   108.781864
# 4  10.733073  0.01474  -0.00002  -0.002133   108.834702

# %%
x = data['Iset (A)'].values/1e-6 # uA
y = data['Vmeas (V)'].values/1e-3 # mV
y = y-y[len(y)//2] # remove offset
id1 = np.where(x>0)[0]
id2 = np.where(x<0)[0]

plt.plot(x[id1],y[id1],'.-')
plt.plot(-x[id2+1],-y[id2])
plt.xlim(0,12.5)
plt.ylim(0,1.5)
plt.grid()
# plt.xlim(5.5,6.5)
# plt.ylim(0,0.5)
plt.show()
plt.close()

# %%
plt.plot(x,np.gradient(y,x)*1000)
plt.ylim(0,300)
# plt.yscale('log')
plt.xlabel('Bias current (uA)')
plt.ylabel('dVdI (Ohm)')
plt.show()
plt.close()

# %%
panel_iv = {'x1':x[id1],'y1':y[id1],
          'x2':-x[id2+1],'y2':-y[id2],
          'xlabel':r'Bias current (µA)','ylabel':'Voltage (mV)'}
pickle.dump(panel_iv,open('data_final/fig1_panel_iv.pkl','wb'))

# %% [markdown]
# # SM 50 Hz

# %%
myfile = sorted(glob.glob('data_raw/F13*/*.dat'))
myfile = myfile[0]
# print(myfile)
data = stlabutils.readdata.readdat(myfile)
mymtx = stlabutils.framearr_to_mtx(data,'S21dB (dB)',xkey='Frequency (Hz)',ykey='Iset (A)')
mymtx.applystep('rotate_ccw')
# mymtx.applystep('sub_linecut 0,1')
# mymtx.applystep('lowpass 0,1')
# Out:
# ['Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)', 'T (K)', 'Time (s)', 'Iset (A)', 'Vmeas (V)']
# ('Frequency (Hz)', 'S21re ()', 'S21im ()', 'S21dB (dB)', 'S21Ph (rad)', 'Power (dBm)', 'T (K)', 'Time (s)', 'Iset (A)', 'Vmeas (V)')
# Iset (A)
# Frequency (Hz)
# (81, 2001)
# rotate_ccw []

# %%
wbval=(0.4, 0.4)
cmap='YlGn_r'
lims = np.percentile(mymtx.pmtx.values, (wbval[0], 100 - wbval[1]))
vmin = lims[0]
vmax = lims[1]
extents = mymtx.getextents()
dx = np.diff(mymtx.pmtx.axes[1].values)[0]
dy = np.diff(mymtx.pmtx.axes[0].values)[0]

x = mymtx.pmtx.axes[1]-dx/2 # why??
y = mymtx.pmtx.axes[0]-dy/2
X,Y = np.meshgrid(x,y)
Z = mymtx.pmtx.values

Z = Z-np.max(Z)
lims = np.percentile(Z, (wbval[0], 100 - wbval[1]))
vmin = lims[0]
vmax = lims[1]


# Z = Z/np.linalg.norm(Z)
# normalizing
# Z = Z - Z.min(axis=0)
# Z = Z / (Z.min(axis=0) - Z.max(axis=0))
# Z = -Z

fig,ax=plt.subplots()
plt.pcolormesh(X/1e-6,Y/1e9,Z,cmap=cmap,vmin=vmin,vmax=vmax)
# plt.xlim(0,8.5)
plt.ylim(7.355,7.445)

plt.ylabel('Frequency (GHz)')
plt.xlabel('Bias current (µA)')

plt.colorbar()

plt.show()
plt.close()

# %%
pkldict = {
    'xlabel':r'Bias current (µA)','ylabel':'Frequency (GHz)','zlabel':'S11dB (dB)',
    'X':X/1e-6,'Y':Y/1e9,'Z':Z,
    'vmin':vmin,'vmax':vmax
}
pickle.dump(pkldict,open('data_final/SM_S11_50Hz.pkl','wb'))

# %%
idx = [np.arange(450,640),np.arange(660,840),np.arange(860,1150)]
idx_dat = [65,70,75]
for i,xx in zip(idx_dat,idx):
    x = Y[xx,i]/1e9
    y = Z[xx,i]
    Iset = X[0,i]/1e-6
    plt.plot(x,y,label=Iset)
plt.xlabel('Frequency (GHz)')
plt.ylabel('S21dB (dB)')
plt.legend()
# plt.xlim(7.38,7.44)
plt.show()
plt.close()

# %%
pkldict = {
    'xlabel':'Frequency (GHz)','ylabel':'S11dB (dB)',
    'x1':Y[idx[0],idx_dat[0]]/1e9,
    'x2':Y[idx[1],idx_dat[1]]/1e9,
    'x3':Y[idx[2],idx_dat[2]]/1e9,
    'y1':Z[idx[0],idx_dat[0]],
    'y2':Z[idx[1],idx_dat[1]],
    'y3':Z[idx[2],idx_dat[2]],
    'z1':X[0,idx_dat[0]]/1e-6,
    'z2':X[0,idx_dat[1]]/1e-6,
    'z3':X[0,idx_dat[2]]/1e-6,
}
pickle.dump(pkldict,open('data_final/SM_S11_50Hz_linecuts.pkl','wb'))

# %% [markdown]
# ## quantifying

# %%
tuning = pickle.load(open('data_final/fig2_panel_f0fit.pkl','rb'))
params=tuning['params']
ii = np.linspace(0,8e-6,1001)
myf0 = f0model(ii,fr=params['fr'],Lr=params['Lr'],Ic=params['Ic'])

# %%
xx = pkldict['x1']
yy = pkldict['y1']
zz = pkldict['z1']
print('Bias point =',zz,'uA')
plt.plot(xx,yy)
vector = abs(yy)
indexes, _ = scipy.signal.find_peaks(vector,height=7,distance=15)
plt.plot(xx[indexes],yy[indexes],'o')

freqs = xx[indexes]
deltaF = np.diff(freqs)*1e9/1e6
deltaF # in MHz

myG1 = np.gradient(myf0/1e6,ii/1e-6) # MHz/uA

dfdI = interp1d(ii,myG1)(zz*1e-6)
print('at bias point: df/dI = ',dfdI,'MHz/uA')

Inoise = deltaF/dfdI
print('at bias point: Inoise =',Inoise,'uA')
# Out:
# Bias point = 4.9 uA
# at bias point: df/dI =  -7.323963289032695 MHz/uA
# at bias point: Inoise = [0.13926886] uA

# %%
xx = pkldict['x2']
yy = pkldict['y2']
zz = pkldict['z2']
print('Bias point =',zz,'uA')
plt.plot(xx,yy)
vector = abs(yy)
indexes, _ = scipy.signal.find_peaks(vector,height=5.5,distance=20)
plt.plot(xx[indexes],yy[indexes],'o')
plt.grid()

freqs = xx[indexes]
deltaF = np.diff(freqs)*1e9/1e6
deltaF # in MHz

myG1 = np.gradient(myf0/1e6,ii/1e-6) # MHz/uA

dfdI = interp1d(ii,myG1)(zz*1e-6)
print('at bias point: df/dI = ',dfdI,'MHz/uA')

Inoise = deltaF/dfdI
print('at bias point: Inoise =',Inoise,'uA')
# Out:
# Bias point = 5.9 uA
# at bias point: df/dI =  -11.834133864147596 MHz/uA
# at bias point: Inoise = [0.14703231] uA

# %%
xx = pkldict['x3']
yy = pkldict['y3']
zz = pkldict['z3']
print('Bias point =',zz,'uA')
plt.plot(xx,yy)
vector = abs(yy)
indexes, _ = scipy.signal.find_peaks(vector,height=4,distance=50)
plt.plot(xx[indexes],yy[indexes],'o')
plt.grid()

freqs = xx[indexes]
deltaF = np.diff(freqs)*1e9/1e6
deltaF # in MHz

myG1 = np.gradient(myf0/1e6,ii/1e-6) # MHz/uA

dfdI = interp1d(ii,myG1)(zz*1e-6)
print('at bias point: df/dI = ',dfdI,'MHz/uA')

Inoise = deltaF/dfdI
print('at bias point: Inoise =',Inoise,'uA')
# Out:
# Bias point = 6.9 uA
# at bias point: df/dI =  -21.610895468737017 MHz/uA
# at bias point: Inoise = [0.24709758] uA
